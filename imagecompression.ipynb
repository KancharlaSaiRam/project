# %%
#Okay, let's import this image called "wild.png", stored in the same working directory as this notebook. import matplotlib.image as mpimg img = mpimg.imread('wild.png') #Now, let's look at the size of this numpy array object img as well as plot it using imshow. print img.shape plt.axis('off') plt.imshow(img) - See more at: https://shankarmsy.github.io/posts/pca-sklearn.html#sthash.8d2yD0O9.dpuf

# %%
import matplotlib.image as mpimg 
img = mpimg.imread('/home/ramchowdary/Documents/farewell/New Doc 2017-12-14_18.jpg')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.decomposition

# %%
print(img.shape) 
#plt.axis('off') 
plt.imshow(img)
plt.show()
# Out:
# (908, 776, 3)

# %%
776*3
# Out:
# 2328

# %%
img_r = np.reshape(img, (908, 2328)) # re shape that image

# %%
img_r.shape
# Out:
# (908, 2328)

# %%
plt.imshow(img_r)
plt.show()

# %%
#from sklearn.decomposition import PCA
from sklearn import decomposition
pca = decomposition.PCA()

# %%
pca.n_components = 700 # 8x8

# %%
pca_data = pca.fit_transform(img_r)

# %%
#img_c = pca.transform(img_r) # transform the data

# %%
pca_data.shape
# Out:
# (908, 700)

# %%
#img_c.shape

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.99999871116693551

# %%
img_c=pca.inverse_transform(pca_data)

# %%
img_c.shape
# Out:
# (908, 2328)

# %%
new=np.reshape(img_c,(908, 776, 3))

# %%
new.shape
# Out:
# (908, 776, 3)

# %%
plt.imshow(img_c)

# %%
type(new)
# Out:
# numpy.ndarray

# %%
#plt.axis('off')
#plt.imshow(new)

# %%
pca_data.shape
# Out:
# (908, 700)

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.99999871116693551

# %%
img_c=np.reshape(img_r,(908, 2328))

# %%
img_c.shape
# Out:
# (908, 2328)

# %%
img_r.shape
# Out:
# (908, 2328)

# %%
plt.imshow(img_c)
plt.show()

# %%
img_c.shape
# Out:
# (908, 2328)

# %%
temp = pca.inverse_transform(img_c)

# %%
temp = np.reshape(temp, (908, 776, 3))

# %%
temp.shape
# Out:
# (908, 776, 3)

# %%
#plt.imshow(temp)

# %%
np.reshape(temp, (908, 776, 3))
# Out:
# array([[[ 169.84148678,  129.805561  ,  117.61565368],
#         [ 169.08832956,  129.18606582,  116.85763729],
#         [ 168.1110585 ,  128.5264922 ,  116.32544409],
#         ...,
#         [ 133.83845222,  103.32698501,   89.03860028],
#         [ 118.58866906,   86.42950771,   70.42292833],
#         [ 109.14836705,   77.09811496,   61.09051796]],
#
#        [[ 171.72829149,  131.83487265,  120.2828005 ],
#         [ 170.70765786,  130.93731687,  119.25164574],
#         [ 169.43281574,  130.0653418 ,  118.46928822],
#         ...,
#         [ 133.70944658,  103.73828219,   89.43318642],
#         [ 118.40706032,   86.74292346,   70.70722695],
#         [ 108.96847761,   77.36337122,   61.32321948]],
#
#        [[ 173.87859884,  134.21874163,  123.01473127],
#         [ 172.40965117,  132.87116243,  121.54031222],
#         [ 170.84868126,  131.71375692,  120.44332295],
#         ...,
#         [ 133.93960938,  103.8010117 ,   89.30240344],
# ...

# %%
# new

# %% [markdown]
# 1.normalization
# 2.covariance
# 3.eighen vectors
# 4.reconstruction
