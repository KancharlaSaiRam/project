# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/ramchowdary/irisdataset.csv")

# %%
# column names in our dataset
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# how many data points and features
df.shape # it containing 120 rows and 5 collumns
# Out:
# (150, 5)

# %%
df['species'].value_counts()
# it containing 3 equal species of the flowers.
# so it is balanced
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
# 2-D

# %%
# this is general scatter plot
df.plot(kind='scatter',x = "sepal_length",y="sepal_width")
plt.show()

# %%
# don't observe anything because all are same

# %%
# colored plots
# style must be one of white, dark, whitegrid, darkgrid, ticks

sns.set_style("whitegrid")
sns.FacetGrid(df,hue="species",height = 4).map(plt.scatter,"sepal_length",'sepal_width').add_legend()
plt.show()

# %%
# here setosa represents the BLUE
#  versicolor represents the ORANGE
#   virginica represents the GREEN

# %%
# based on 2 columns setosa is differ

# %%
# draw the pairplot()

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df)
plt.show() # can't identify or observe the difference between the 3 colors

# %%
sns.pairplot(df,hue="species",height=3)

# %%
sns.set_style("whitegrid")
sns.pairplot(df,hue="species",height=3)
plt.show()

# %%
# observations:

# %%
# if the petal_length is 1 to 2  that type of flowers are called SETOSA
# if petal leangth is greater than 2 AND less than 5   that type of flowers are called VERSICOLOR
# if petal leangth is greater than 5 that type of flowers are called VIRGINICA
# HERE OBSERVE  PETAL_LENGTH AND PETAL_WIDTH are important. 
# petal_leangth is the important feature

# %% [markdown]
# # code:

# %%
'''
if df['petal_length']<= 2 and df['petal_width']<1:
    print("setosa")
elif (df['petal_length']>2 and df['petal_length'] <= 5) and (df['petal_width'] >= 1 and df['petal_width']<=1.7):
    print("versicolor")
else:
    print("verginica")
'''
# Out:
# '\nif df[\'petal_length\']<= 2 and df[\'petal_width\']<1:\n    print("setosa")\nelif (df[\'petal_length\']>2 and df[\'petal_length\'] <= 5) and (df[\'petal_width\'] >= 1 and df[\'petal_width\']<=1.7):\n    print("versicolor")\nelse:\n    print("verginica")\n'

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
import numpy as np

# %%
iris_setosa = df.loc[df["species"]== "setosa"]
iris_versicolor = df.loc[df["species"]=='versicolor']
iris_virginica = df.loc[df['species']=='virginica']

# %%
plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa['petal_length']))
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_versicolor['petal_length']))
plt.plot(iris_virginica['petal_length'],np.zeros_like(iris_virginica['petal_length']))
plt.show()
# plotting on the line can't observe because versica and virginica flowers

# %%
# from this 1-d plot can't seperate the species
# can't classify using this type of plot
# so we use the histograms.

# %%
sns.FacetGrid(df,hue='species',height=5).map(sns.distplot,"petal_length").add_legend()
plt.show()

# %%
# from this graph easily seperate the species based on their category.
# smooth line represents the PDF
# pdf means probability density function
# pdf says roughly what is the no of points that i will encountered at

# %%
# pl<2 : setosa
# pl>2 and pl<= 4.7:versicolor
# else: virginica

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
# univariate analysis means analysing the data on one variable

# %%
# petal_length
sns.FacetGrid(df,hue="species",height=3).map(sns.distplot,"petal_length").add_legend()
plt.show()

# %%
# observation:
# 1. setosa flowers are seperable . but versicolor and virginica flowers are overlapping
# 2. find the threshold based on the pdfs

# %%
# petal_width
sns.FacetGrid(df,hue="species",height=3).map(sns.distplot,"petal_width").add_legend()
plt.show()

# %%
# observation:

# %%
# sepal_leangth:
sns.FacetGrid(df,hue="species",height=3).map(sns.distplot,"sepal_length").add_legend()
plt.show()
# this feature variable can't classify

# %%
# sepal_width
sns.FacetGrid(df,hue="species",height=3).map(sns.distplot,'sepal_width').add_legend()
plt.show()

# %%
# from the above plots observe which one is important feature to classify
# from the above information petal_length is important feture variable

# %% [markdown]
# # cumulative DISTRIBUTION FUNCTION

# %%
counts,bin_edges = np.histogram(iris_setosa["petal_length"],bins=10,density=True)
pdf = counts/sum(counts)
print(pdf)
print(bin_edges)
# cdf
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf);

plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
# Plots of CDF of petal_length for various types of flowers.

# Misclassification error if you use petal_length only.

counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


# virginica
counts, bin_edges = np.histogram(iris_virginica['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


#versicolor
counts, bin_edges = np.histogram(iris_versicolor['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %%
# by using this find how accuracy have the 3 types of flowers

# %% [markdown]
# # mean

# %%
df.mean()
# it prints all the means
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %%
df.median()
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
# RANDOM NUMBER GENERATOR

# %%
import random
random.random() # it gives the value between 0 to 1.
# Out:
# 0.1310632886513734

# %%
# load the data
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
 DF = df.drop(['species'],axis=1)

# %%
DF.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
DF.shape
# Out:
# (150, 4)

# %%
n=150
m=30
p=m/n
l=[]
for i in range(0,n):
    if random.random() <=p:
        l.append(DF[i:])
len(l)
# Out:
# 36

# %%
type(l)
# Out:
# list

# %%
# 
m=150
n=30
p=0.2
l=[]
for i in range(0,150):
    if random.random()<= p:
        l.append(DF[i:])
len(l)
# Out:
# 46
